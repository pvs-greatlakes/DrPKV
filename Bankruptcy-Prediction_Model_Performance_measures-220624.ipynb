# %%
import  os

folder           =  r'D:\DrPKV\20220618\DrPKV-main'
file1            =  r'D:\DrPKV\20220618\Output\Predicted_Values_train_data_2022_06_24_11_39_36.csv'
file2            =  r'D:\DrPKV\20220618\Output\Predicted_Values_test_data_2022_06_24_11_39_36.csv'

os.chdir(folder)

# %%
import   pandas            as      pd
from     sklearn           import  metrics
from     sklearn.metrics   import  classification_report
import   seaborn           as      sns
import   matplotlib.pyplot as      plt

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
def measures_cm(model, datatype, act, pred):
   
    c_matrix = pd.crosstab(act,pred, rownames=['Actual'], colnames=['Predicted'])

    print("\nModel performance of %s" %model)
    print("\nDataset used %s" %datatype)

    sns.heatmap(c_matrix, annot = True, fmt = '.6g')
    plt.show()
    target_names = ['NPA', 'Healthy']
    print(classification_report(act, pred, target_names = target_names))

# %%
def draw_roc( actual, probs ):

    import pandas            as   pd
    import numpy             as   np
    import seaborn           as   sns
    import matplotlib.pyplot as   plt
    import sklearn.metrics   as   metrics
    import seaborn           as   sns
    
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
    drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 4))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
df_train       =    pd.read_csv(file1)
print('Train data shape {}'.format(df_train.shape))
# Out:
# Train data shape (6300, 9)

# %%
df_train.columns
# Out:
# Index(['Train_y_true', 'LR_Train_y_pred', 'CART_Train_y_pred',
#        'RF_Train_y_pred', 'SVC_Train_y_pred', 'LDA_Train_y_pred',
#        'KNN_Train_y_pred', 'XGBoost_Train_y_pred', 'Consensus-3 models'],
#       dtype='object')

# %%
df_test       =    pd.read_csv(file2)
print('Test data shape {}'.format(df_test.shape))
# Out:
# Test data shape (2700, 9)

# %%
df_test.columns
# Out:
# Index(['Test_y_true', 'LR_Test_y_pred', 'CART_Test_y_pred', 'RF_Test_y_pred',
#        'SVC_Test_y_pred', 'LDA_Test_y_pred', 'KNN_Test_y_pred',
#        'XGBoost_Test_y_pred', 'Consensus-3 models'],
#       dtype='object')

# %%
Col_Models_List =  ['LR_Train_y_pred', 'CART_Train_y_pred', 'RF_Train_y_pred', 'SVC_Train_y_pred', 'LDA_Train_y_pred',\
                     'KNN_Train_y_pred', 'Consensus-3 models']

# %%
for each in Col_Models_List:
    act_tr     =   df_train.loc[:, 'Train_y_true']  
    pred_tr    =   df_train.loc[:, each]  
    measures_cm(each, 'Training dataset', act_tr, pred_tr)
    draw_roc(act_tr, pred_tr)
# Out:
# Model performance of LR_Train_y_pred
#
# Dataset used Training dataset
#               precision    recall  f1-score   support
#
#          NPA       0.22      0.23      0.23       927
#      Healthy       0.87      0.86      0.86      5373
#
#     accuracy                           0.77      6300
#    macro avg       0.54      0.55      0.55      6300
# weighted avg       0.77      0.77      0.77      6300
# Model performance of CART_Train_y_pred
#
# Dataset used Training dataset
#               precision    recall  f1-score   support
#
#          NPA       1.00      1.00      1.00       927
#      Healthy       1.00      1.00      1.00      5373
#
#     accuracy                           1.00      6300
#    macro avg       1.00      1.00      1.00      6300
# weighted avg       1.00      1.00      1.00      6300
# Model performance of RF_Train_y_pred
#
# Dataset used Training dataset
#               precision    recall  f1-score   support
#
# ...

# %%
Col_Models_List =  ['LR_Test_y_pred', 'CART_Test_y_pred', 'RF_Test_y_pred', 'SVC_Test_y_pred', 'LDA_Test_y_pred',\
                    'KNN_Test_y_pred', 'Consensus-3 models']
for each in Col_Models_List:
    act_te     =   df_test.loc[:, 'Test_y_true']  
    pred_te    =   df_test.loc[:, each]  
    measures_cm(each, 'Test dataset', act_te, pred_te)
    draw_roc(act_te, pred_te)
# Out:
# Model performance of LR_Test_y_pred
#
# Dataset used Test dataset
#               precision    recall  f1-score   support
#
#          NPA       0.22      0.25      0.24       398
#      Healthy       0.87      0.85      0.86      2302
#
#     accuracy                           0.76      2700
#    macro avg       0.55      0.55      0.55      2700
# weighted avg       0.77      0.76      0.77      2700
# Model performance of CART_Test_y_pred
#
# Dataset used Test dataset
#               precision    recall  f1-score   support
#
#          NPA       0.99      1.00      0.99       398
#      Healthy       1.00      1.00      1.00      2302
#
#     accuracy                           1.00      2700
#    macro avg       1.00      1.00      1.00      2700
# weighted avg       1.00      1.00      1.00      2700
# Model performance of RF_Test_y_pred
#
# Dataset used Test dataset
#               precision    recall  f1-score   support
#
#          NPA       0.99      1.00      0.99       398
# ...
