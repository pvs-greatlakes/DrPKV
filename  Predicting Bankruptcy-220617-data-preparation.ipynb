# %%
import pandas                   as     pd
import numpy                    as     np
import seaborn                  as     sns
import matplotlib.pyplot        as     plt
import statsmodels.api          as     sm
from   sklearn.preprocessing    import OrdinalEncoder
from   sklearn                  import metrics
from   sklearn                  import tree
import sys, os
import os
os.chdir(r'D:\DrPKV\20220519')

# %%
import time
from    datetime   import datetime
from    datetime   import timedelta

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ### Multiple Imputation by Chained Equation.
#
#
# #### Multiple Imputation by Chained Equation assumes that data is MAR, i.e. missing at random.
#
#
# We observe that on a few occasions, data missing in a dataset and is related to the other features and hence they can be predicted using other feature values.
#
# Ref: https://www.numpyninja.com/post/mice-and-knn-missing-value-imputations-through-python
#
# It cannot be imputed with general ways of using mean, mode, or median which might pollute the data.

# %%
### Imputing missing numerical values using the IterativeImputer class in sklearn 

from sklearn.experimental  import   enable_iterative_imputer
from sklearn.impute        import   IterativeImputer
from sklearn.linear_model   import   LinearRegression

### https://www.numpyninja.com/post/mice-and-knn-missing-value-imputations-through-python

# %%
file_name = './Data/BankruptcyData.xlsx'

# %%
df     =   pd.read_excel(file_name, sheet_name = 'Full data')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 34 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Row                                       9000 non-null   int64
#  1   Year                                      9000 non-null   int64
#  2   Company_name                              9000 non-null   object
#  3   Year Encoded                              9000 non-null   int64
#  4    Dummy Coded :Healthy=1; NPA= 0           9000 non-null   int64
#  5   Asset_turnover                            8299 non-null   float64
#  6   Receivable_turnover(new)                  7390 non-null   float64
#  7   Inventory_turnover                        5702 non-null   float64
#  8   Cash_ratio                                8278 non-null   float64
#  9   Quick_ratio                               8278 non-null   float64
#  10  Current_ratio                             8278 non-null   float64
#  11  ROA(new)                                  8319 non-null   float64
#  12  ROE(new)                                  8301 non-null   float64
#  13  ROS(new)                                  8420 non-null   float64
#  14  ROI(new)                                  4868 non-null   float64
#  15  debt_asset                                8319 non-null   float64
#  16  debt_equity                               8301 non-null   float64
#  17  debt_income                               8882 non-null   float64
#  18  Interest_coverage                         7431 non-null   float64
#  19  Asset_coverage                            7694 non-null   float64
#  20  EBIT_Sales                                8420 non-null   float64
#  21  Sales_CE                                  8281 non-null   float64
#  22  ROCE_CE                                   7742 non-null   float64
#  23  Changeinsales_Industry                    8987 non-null   float64
#  24  Grossvaluedadded                          8987 non-null   float64
#  25  Ln_GVA                                    8987 non-null   float64
#  26  Operating Cash Flow/Total Sales           8420 non-null   float64
#  27  Operating Cash Flow/Total Debt            7694 non-null   float64
#  28  Operating Cash Flow/Shareholder's Equity  8301 non-null   float64
#  29  Fixed Asset Turnover Ratio                7993 non-null   float64
#  30  YOY Sales Growth Rate                     8397 non-null   float64
#  31  YOY EBIT Growth Rate                      8858 non-null   float64
#  32  Total shareholders' funds                 8979 non-null   float64
#  33  Shareholderquity_code                     5210 non-null   float64
# dtypes: float64(29), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
df.columns
# Out:
# Index(['Row', 'Year', 'Company_name', 'Year Encoded',
#        ' Dummy Coded :Healthy=1; NPA= 0', 'Asset_turnover',
#        'Receivable_turnover(new)', 'Inventory_turnover', 'Cash_ratio',
#        'Quick_ratio', 'Current_ratio', 'ROA(new)', 'ROE(new)', 'ROS(new)',
#        'ROI(new)', 'debt_asset', 'debt_equity', 'debt_income',
#        'Interest_coverage', 'Asset_coverage', 'EBIT_Sales', 'Sales_CE',
#        'ROCE_CE', 'Changeinsales_Industry', 'Grossvaluedadded', 'Ln_GVA',
#        'Operating Cash Flow/Total Sales', 'Operating Cash Flow/Total Debt',
#        'Operating Cash Flow/Shareholder's Equity',
#        'Fixed Asset Turnover Ratio', 'YOY Sales Growth Rate',
#        'YOY EBIT Growth Rate', 'Total shareholders' funds',
#        'Shareholderquity_code'],
#       dtype='object')

# %% [markdown]
# ### Convert categorical column to numeric

# %% [markdown]
# https://pbpython.com/categorical-encoding.html

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero & Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero & Missing Values'] = 100 * mz_table['Total Zero & Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
#         mz_table.to_excel('D:/sampledata/missing_and_zero_values.xlsx', freeze_panes=(1,0), index = False)
        return mz_table

# %%
mdf =  missing_zero_values_table(df)
mdf.shape
# Out:
# Your selected dataframe has 34 columns and 9000 Rows.
# There are 29 columns that have missing values.
# (29, 6)

# %%
mdf.index
# Out:
# Index(['ROI(new)', 'Shareholderquity_code', 'Inventory_turnover',
#        'Receivable_turnover(new)', 'Interest_coverage',
#        'Operating Cash Flow/Total Debt', 'Asset_coverage', 'ROCE_CE',
#        'Fixed Asset Turnover Ratio', 'Cash_ratio', 'Current_ratio',
#        'Quick_ratio', 'Sales_CE', 'Asset_turnover',
#        'Operating Cash Flow/Shareholder's Equity', 'ROE(new)', 'debt_equity',
#        'debt_asset', 'ROA(new)', 'YOY Sales Growth Rate', 'EBIT_Sales',
#        'ROS(new)', 'Operating Cash Flow/Total Sales', 'YOY EBIT Growth Rate',
#        'debt_income', 'Total shareholders' funds', 'Grossvaluedadded',
#        'Ln_GVA', 'Changeinsales_Industry'],
#       dtype='object')

# %%
mdf
# Out:
#                                           Zero Values  Missing Values  \
# ROI(new)                                           25            4132
# Shareholderquity_code                            3305            3790
# Inventory_turnover                               4364            3298
# Receivable_turnover(new)                          401            1610
# Interest_coverage                                 218            1569
# Operating Cash Flow/Total Debt                     15            1306
# Asset_coverage                                      0            1306
# ROCE_CE                                            70            1258
# Fixed Asset Turnover Ratio                        476            1007
# Cash_ratio                                         21             722
# Current_ratio                                       5             722
# Quick_ratio                                        20             722
# Sales_CE                                          539             719
# Asset_turnover                                    544             701
# Operating Cash Flow/Shareholder's Equity           20             699
# ROE(new)                                           78             699
# debt_equity                                       626             699
# debt_asset                                        625             681
# ROA(new)                                           82             681
# YOY Sales Growth Rate                               5             603
# EBIT_Sales                                        107             580
# ROS(new)                                           14             580
# Operating Cash Flow/Total Sales                    20             580
# YOY EBIT Growth Rate                               11             142
# debt_income                                      1258             118
# Total shareholders' funds                         678              21
# Grossvaluedadded                                    0              13
# Ln_GVA                                              0              13
# Changeinsales_Industry                            138              13
#
#                                           % of Total Values  \
# ROI(new)                                           45.90000
# Shareholderquity_code                              42.10000
# Inventory_turnover                                 36.60000
# Receivable_turnover(new)                           17.90000
# Interest_coverage                                  17.40000
# Operating Cash Flow/Total Debt                     14.50000
# Asset_coverage                                     14.50000
# ROCE_CE                                            14.00000
# Fixed Asset Turnover Ratio                         11.20000
# Cash_ratio                                          8.00000
# Current_ratio                                       8.00000
# Quick_ratio                                         8.00000
# Sales_CE                                            8.00000
# Asset_turnover                                      7.80000
# Operating Cash Flow/Shareholder's Equity            7.80000
# ROE(new)                                            7.80000
# debt_equity                                         7.80000
# debt_asset                                          7.60000
# ROA(new)                                            7.60000
# YOY Sales Growth Rate                               6.70000
# EBIT_Sales                                          6.40000
# ROS(new)                                            6.40000
# Operating Cash Flow/Total Sales                     6.40000
# YOY EBIT Growth Rate                                1.60000
# debt_income                                         1.30000
# Total shareholders' funds                           0.20000
# Grossvaluedadded                                    0.10000
# Ln_GVA                                              0.10000
# Changeinsales_Industry                              0.10000
#
#                                           Total Zero & Missing Values  \
# ROI(new)                                                         4157
# Shareholderquity_code                                            7095
# Inventory_turnover                                               7662
# Receivable_turnover(new)                                         2011
# Interest_coverage                                                1787
# Operating Cash Flow/Total Debt                                   1321
# Asset_coverage                                                   1306
# ROCE_CE                                                          1328
# Fixed Asset Turnover Ratio                                       1483
# Cash_ratio                                                        743
# Current_ratio                                                     727
# Quick_ratio                                                       742
# Sales_CE                                                         1258
# Asset_turnover                                                   1245
# Operating Cash Flow/Shareholder's Equity                          719
# ROE(new)                                                          777
# debt_equity                                                      1325
# debt_asset                                                       1306
# ROA(new)                                                          763
# YOY Sales Growth Rate                                             608
# EBIT_Sales                                                        687
# ROS(new)                                                          594
# Operating Cash Flow/Total Sales                                   600
# YOY EBIT Growth Rate                                              153
# debt_income                                                      1376
# Total shareholders' funds                                         699
# Grossvaluedadded                                                   13
# Ln_GVA                                                             13
# Changeinsales_Industry                                            151
#
#                                           % Total Zero & Missing Values  \
# ROI(new)                                                       46.20000
# Shareholderquity_code                                          78.80000
# Inventory_turnover                                             85.10000
# Receivable_turnover(new)                                       22.30000
# Interest_coverage                                              19.90000
# Operating Cash Flow/Total Debt                                 14.70000
# Asset_coverage                                                 14.50000
# ROCE_CE                                                        14.80000
# Fixed Asset Turnover Ratio                                     16.50000
# Cash_ratio                                                      8.30000
# Current_ratio                                                   8.10000
# Quick_ratio                                                     8.20000
# Sales_CE                                                       14.00000
# Asset_turnover                                                 13.80000
# Operating Cash Flow/Shareholder's Equity                        8.00000
# ROE(new)                                                        8.60000
# debt_equity                                                    14.70000
# debt_asset                                                     14.50000
# ROA(new)                                                        8.50000
# YOY Sales Growth Rate                                           6.80000
# EBIT_Sales                                                      7.60000
# ROS(new)                                                        6.60000
# Operating Cash Flow/Total Sales                                 6.70000
# YOY EBIT Growth Rate                                            1.70000
# debt_income                                                    15.30000
# Total shareholders' funds                                       7.80000
# Grossvaluedadded                                                0.10000
# Ln_GVA                                                          0.10000
# Changeinsales_Industry                                          1.70000
#
#                                          Data Type
# ROI(new)                                   float64
# Shareholderquity_code                      float64
# Inventory_turnover                         float64
# Receivable_turnover(new)                   float64
# Interest_coverage                          float64
# Operating Cash Flow/Total Debt             float64
# Asset_coverage                             float64
# ROCE_CE                                    float64
# Fixed Asset Turnover Ratio                 float64
# Cash_ratio                                 float64
# Current_ratio                              float64
# Quick_ratio                                float64
# Sales_CE                                   float64
# Asset_turnover                             float64
# Operating Cash Flow/Shareholder's Equity   float64
# ROE(new)                                   float64
# debt_equity                                float64
# debt_asset                                 float64
# ROA(new)                                   float64
# YOY Sales Growth Rate                      float64
# EBIT_Sales                                 float64
# ROS(new)                                   float64
# Operating Cash Flow/Total Sales            float64
# YOY EBIT Growth Rate                       float64
# debt_income                                float64
# Total shareholders' funds                  float64
# Grossvaluedadded                           float64
# Ln_GVA                                     float64
# Changeinsales_Industry                     float64

# %% [markdown]
# ### Drop variables having more than 40% of missing values
# 1. ROI(new)
# 2. Shareholderquity_code

# %% [markdown]
# ### The following variables,all numerical type are having missing values
#
# *  1) 'Inventory_turnover'
# *  2) 'Receivable_turnover(new)'
# *  3) 'Interest_coverage'
# *  4) 'Asset_coverage'
# *  5) 'Operating Cash Flow/Total Debt'
# *  6) 'ROCE_CE'
# *  7) 'Fixed Asset Turnover Ratio'
# *  8) 'Cash_ratio'
# *  9) 'Quick_ratio'
# * 10) 'Current_ratio'
# * 11) 'Sales_CE'
# * 12) 'Asset_turnover'
# * 13) 'debt_equity'
# * 14) 'ROE(new)'
# * 15) "Operating Cash Flow/Shareholder's Equity"
# * 16) 'debt_asset'
# * 17) 'ROA(new)'
# * 18) 'YOY Sales Growth Rate'
# * 19) 'EBIT_Sales'
# * 20) 'ROS(new)'
# * 21) 'Operating Cash Flow/Total Sales'
# * 22) 'YOY EBIT Growth Rate'
# * 23) 'debt_income'
# * 24) "Total shareholders' funds"
# * 25) 'Changeinsales_Industry'
# * 26) 'Grossvaluedadded'
# * 27) 'Ln_GVA'

# %%
print("\nBefore removing null values \n Rows %d Columns %d" % (df.shape[0], df.shape[1]))
df.drop(['ROI(new)','Shareholderquity_code' ], axis = 1, inplace = True)
print("\nAfter removing null values \n Rows %d Columns %d" % (df.shape[0], df.shape[1]))
# Out:
# Before removing null values
#  Rows 9000 Columns 34
#
# After removing null values
#  Rows 9000 Columns 32

# %%
num_variables_df = df.select_dtypes(include = 'number')
print(num_variables_df.shape)
print(num_variables_df.columns)
# Out:
# (9000, 31)
# Index(['Row', 'Year', 'Year Encoded', ' Dummy Coded :Healthy=1; NPA= 0',
#        'Asset_turnover', 'Receivable_turnover(new)', 'Inventory_turnover',
#        'Cash_ratio', 'Quick_ratio', 'Current_ratio', 'ROA(new)', 'ROE(new)',
#        'ROS(new)', 'debt_asset', 'debt_equity', 'debt_income',
#        'Interest_coverage', 'Asset_coverage', 'EBIT_Sales', 'Sales_CE',
#        'ROCE_CE', 'Changeinsales_Industry', 'Grossvaluedadded', 'Ln_GVA',
#        'Operating Cash Flow/Total Sales', 'Operating Cash Flow/Total Debt',
#        'Operating Cash Flow/Shareholder's Equity',
#        'Fixed Asset Turnover Ratio', 'YOY Sales Growth Rate',
#        'YOY EBIT Growth Rate', 'Total shareholders' funds'],
#       dtype='object')

# %%
lreg         =  LinearRegression()
imp          =  IterativeImputer(estimator= lreg, missing_values = np.nan, max_iter = 10, verbose = 2,\
                                 imputation_order= 'roman',random_state = 0)
X            =  imp.fit_transform(num_variables_df)
# Out:
# [IterativeImputer] Completing matrix with shape (9000, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.47
# [IterativeImputer] Change: 4378730442.761648, scaled tolerance: 350030860.0
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.78
# [IterativeImputer] Change: 2741521048.0803456, scaled tolerance: 350030860.0
# [IterativeImputer] Ending imputation round 3/10, elapsed time 1.07
# [IterativeImputer] Change: 108970542.8637385, scaled tolerance: 350030860.0
# [IterativeImputer] Early stopping criterion reached.

# %%
X_df           =    pd.DataFrame(X, columns = ['Row', 'Year', 'Year Encoded', 'Dummy Coded :Healthy=1; NPA= 0',
       'Asset_turnover', 'Receivable_turnover(new)', 'Inventory_turnover',
       'Cash_ratio', 'Quick_ratio', 'Current_ratio', 'ROA(new)', 'ROE(new)',
       'ROS(new)', 'debt_asset', 'debt_equity', 'debt_income',
       'Interest_coverage', 'Asset_coverage', 'EBIT_Sales', 'Sales_CE',
       'ROCE_CE', 'Changeinsales_Industry', 'Grossvaluedadded', 'Ln_GVA',
       'Operating Cash Flow/Total Sales', 'Operating Cash Flow/Total Debt',
       'Operating Cash Flow/Shareholder"s Equity',
       'Fixed Asset Turnover Ratio', 'YOY Sales Growth Rate',
       'YOY EBIT Growth Rate', 'Total shareholders" funds'])
missing_zero_values_table(X_df)
# Out:
# Your selected dataframe has 31 columns and 9000 Rows.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Zero Values, Missing Values, % of Total Values, Total Zero & Missing Values, % Total Zero & Missing Values, Data Type]
# Index: []

# %%
X_df['Row']                                  =  X_df['Row'].astype(int)
X_df['Year']                                 =  X_df['Year'].astype(int)
X_df['Year Encoded']                         =  X_df['Year Encoded'].astype(int)
X_df['Dummy Coded :Healthy=1; NPA= 0']       =  X_df['Dummy Coded :Healthy=1; NPA= 0'].astype(int)

# %%
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Row                                       9000 non-null   int32
#  1   Year                                      9000 non-null   int32
#  2   Year Encoded                              9000 non-null   int32
#  3   Dummy Coded :Healthy=1; NPA= 0            9000 non-null   int32
#  4   Asset_turnover                            9000 non-null   float64
#  5   Receivable_turnover(new)                  9000 non-null   float64
#  6   Inventory_turnover                        9000 non-null   float64
#  7   Cash_ratio                                9000 non-null   float64
#  8   Quick_ratio                               9000 non-null   float64
#  9   Current_ratio                             9000 non-null   float64
#  10  ROA(new)                                  9000 non-null   float64
#  11  ROE(new)                                  9000 non-null   float64
#  12  ROS(new)                                  9000 non-null   float64
#  13  debt_asset                                9000 non-null   float64
#  14  debt_equity                               9000 non-null   float64
#  15  debt_income                               9000 non-null   float64
#  16  Interest_coverage                         9000 non-null   float64
#  17  Asset_coverage                            9000 non-null   float64
#  18  EBIT_Sales                                9000 non-null   float64
#  19  Sales_CE                                  9000 non-null   float64
#  20  ROCE_CE                                   9000 non-null   float64
#  21  Changeinsales_Industry                    9000 non-null   float64
#  22  Grossvaluedadded                          9000 non-null   float64
#  23  Ln_GVA                                    9000 non-null   float64
#  24  Operating Cash Flow/Total Sales           9000 non-null   float64
#  25  Operating Cash Flow/Total Debt            9000 non-null   float64
#  26  Operating Cash Flow/Shareholder"s Equity  9000 non-null   float64
#  27  Fixed Asset Turnover Ratio                9000 non-null   float64
#  28  YOY Sales Growth Rate                     9000 non-null   float64
#  29  YOY EBIT Growth Rate                      9000 non-null   float64
#  30  Total shareholders" funds                 9000 non-null   float64
# dtypes: float64(27), int32(4)
# memory usage: 2.0 MB

# %%
X_df.isnull().sum()
# Out:
# Row                                         0
# Year                                        0
# Year Encoded                                0
# Dummy Coded :Healthy=1; NPA= 0              0
# Asset_turnover                              0
# Receivable_turnover(new)                    0
# Inventory_turnover                          0
# Cash_ratio                                  0
# Quick_ratio                                 0
# Current_ratio                               0
# ROA(new)                                    0
# ROE(new)                                    0
# ROS(new)                                    0
# debt_asset                                  0
# debt_equity                                 0
# debt_income                                 0
# Interest_coverage                           0
# Asset_coverage                              0
# EBIT_Sales                                  0
# Sales_CE                                    0
# ROCE_CE                                     0
# Changeinsales_Industry                      0
# Grossvaluedadded                            0
# Ln_GVA                                      0
# Operating Cash Flow/Total Sales             0
# Operating Cash Flow/Total Debt              0
# Operating Cash Flow/Shareholder"s Equity    0
# Fixed Asset Turnover Ratio                  0
# YOY Sales Growth Rate                       0
# YOY EBIT Growth Rate                        0
# Total shareholders" funds                   0
# dtype: int64

# %% [markdown]
# ### Convert categorical column to numeric column

# %%
ord_enc             = OrdinalEncoder()
df["Company Code"]  = ord_enc.fit_transform(df[["Company_name"]])
df[["Company Code", "Company_name"]].head(11)
# Out:
#     Company Code                                       Company_name
# 0       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 1       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 2       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 3       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 4       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 5       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 6       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 7       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 8       51.00000  ASCO NUMATICS (INDIA) PRIVATE LIMITED - Asco N...
# 9       52.00000  ASCOT HOTELS AND RESORTS PRIVATE LIMITED - Asc...
# 10      52.00000  ASCOT HOTELS AND RESORTS PRIVATE LIMITED - Asc...

# %% [markdown]
# ### Retain the numeric column, Company Code and drop the column Company_name

# %%
df.drop(['Company_name'], axis = 1, inplace = True)

# %% [markdown]
# ### Rename the column " Dummy Coded \:Healthy=1; NPA= 0" as "Target"

# %%
df.rename({"Dummy Coded \:Healthy=1; NPA= 0" : 'Target'}, inplace = True)

# %%
collist  = [ "Row", "Year", "Company_name", "Year Encoded",\
"Target", "Asset_turnover",\
"Receivable_turnover(new)", "Inventory_turnover", "Cash_ratio",\
"Quick_ratio", "Current_ratio", "ROA(new)", "ROE(new)", "ROS(new)",\
 "debt_asset", "debt_equity", "debt_income",\
"Interest_coverage", "Asset_coverage", "EBIT_Sales", "Sales_CE",\
"ROCE_CE", "Changeinsales_Industry", "Grossvaluedadded", "Ln_GVA",\
"Operating Cash Flow/Total Sales", "Operating Cash Flow/Total Debt",\
"Operating Cash Flow/Shareholder's Equity",\
"Fixed Asset Turnover Ratio", "YOY Sales Growth Rate",\
"YOY EBIT Growth Rate", "Total shareholders' funds"]

# %%
df.columns = collist

# %%
print(collist);print(len(collist))
# Out:
# ['Row', 'Year', 'Company_name', 'Year Encoded', 'Target', 'Asset_turnover', 'Receivable_turnover(new)', 'Inventory_turnover', 'Cash_ratio', 'Quick_ratio', 'Current_ratio', 'ROA(new)', 'ROE(new)', 'ROS(new)', 'debt_asset', 'debt_equity', 'debt_income', 'Interest_coverage', 'Asset_coverage', 'EBIT_Sales', 'Sales_CE', 'ROCE_CE', 'Changeinsales_Industry', 'Grossvaluedadded', 'Ln_GVA', 'Operating Cash Flow/Total Sales', 'Operating Cash Flow/Total Debt', "Operating Cash Flow/Shareholder's Equity", 'Fixed Asset Turnover Ratio', 'YOY Sales Growth Rate', 'YOY EBIT Growth Rate', "Total shareholders' funds"]
# 32

# %%
collist1 =  X_df.columns

# %%
len(collist1)
# Out:
# 31

# %%
collist1
# Out:
# Index(['Row', 'Year', 'Year Encoded', 'Dummy Coded :Healthy=1; NPA= 0',
#        'Asset_turnover', 'Receivable_turnover(new)', 'Inventory_turnover',
#        'Cash_ratio', 'Quick_ratio', 'Current_ratio', 'ROA(new)', 'ROE(new)',
#        'ROS(new)', 'debt_asset', 'debt_equity', 'debt_income',
#        'Interest_coverage', 'Asset_coverage', 'EBIT_Sales', 'Sales_CE',
#        'ROCE_CE', 'Changeinsales_Industry', 'Grossvaluedadded', 'Ln_GVA',
#        'Operating Cash Flow/Total Sales', 'Operating Cash Flow/Total Debt',
#        'Operating Cash Flow/Shareholder"s Equity',
#        'Fixed Asset Turnover Ratio', 'YOY Sales Growth Rate',
#        'YOY EBIT Growth Rate', 'Total shareholders" funds'],
#       dtype='object')

# %%
diff1 =  set(collist) - set(collist1)
print(diff1)
# Out:
# {"Operating Cash Flow/Shareholder's Equity", "Total shareholders' funds", 'Target', 'Company_name'}

# %%
new_df      =    X_df.copy()

# %%
new_df['Company_name']  =  df['Company_name']

# %%
new_df.head().T
# Out:
#                                                         0                1  \
# Row                                               1.00000          1.00000
# Year                                           2010.00000       2011.00000
# Year Encoded                                     -8.00000         -7.00000
# Dummy Coded :Healthy=1; NPA= 0                    1.00000          1.00000
# Asset_turnover                                    0.00000          0.75666
# Receivable_turnover(new)                          0.00000          3.46077
# Inventory_turnover                                0.00000          0.00000
# Cash_ratio                                        2.01764          1.55843
# Quick_ratio                                       1.55202          1.08407
# Current_ratio                                     3.73717          3.03393
# ROA(new)                                          0.31478          0.29401
# ROE(new)                                          0.39534          0.38944
# ROS(new)                                         -8.83339          0.28722
# debt_asset                                        0.01114          0.01256
# debt_equity                                       0.01399          0.01663
# debt_income                                       0.03539          0.04271
# Interest_coverage                                 0.00000      13054.52217
# Asset_coverage                                   42.44519         41.97329
# EBIT_Sales                                      821.15367          0.38857
# Sales_CE                                          0.00000          1.00223
# ROCE_CE                                           0.39534          0.38944
# Changeinsales_Industry                            0.11152          0.11152
# Grossvaluedadded                            1367257.98989    1409985.57101
# Ln_GVA                                           14.12832         14.15909
# Operating Cash Flow/Total Sales                 821.36928          0.41343
# Operating Cash Flow/Total Debt                   29.35541         24.91447
# Operating Cash Flow/Shareholder"s Equity          0.41067          0.41436
# Fixed Asset Turnover Ratio                        0.00000          2.77352
# YOY Sales Growth Rate                          3231.61719          0.06378
# YOY EBIT Growth Rate                             -0.30656         -0.00279
# Total shareholders" funds                1439044420.00000 1012901796.00000
# Company_name                                     -8.00000         -7.00000
#
#                                                        2               3  \
# Row                                              1.00000         1.00000
# Year                                          2012.00000      2013.00000
# Year Encoded                                    -6.00000        -5.00000
# Dummy Coded :Healthy=1; NPA= 0                   1.00000         1.00000
# Asset_turnover                                   1.07063         1.18632
# Receivable_turnover(new)                         3.95393         4.54417
# Inventory_turnover                               0.00000         0.00000
# Cash_ratio                                       0.85337         0.96842
# Quick_ratio                                      0.38471         0.37537
# Current_ratio                                    2.56104         2.98033
# ROA(new)                                         0.38998         0.38976
# ROE(new)                                         0.52113         0.49546
# ROS(new)                                         0.28324         0.29300
# debt_asset                                       0.01449         0.01640
# debt_equity                                      0.01936         0.02084
# debt_income                                      0.03716         0.04207
# Interest_coverage                             5013.55912     11197.65504
# Asset_coverage                                  43.45664        37.19646
# EBIT_Sales                                       0.36426         0.32854
# Sales_CE                                         1.43067         1.50804
# ROCE_CE                                          0.52113         0.49546
# Changeinsales_Industry                           0.11152         0.11152
# Grossvaluedadded                           1486873.25880   1560709.11650
# Ln_GVA                                          14.21219        14.26065
# Operating Cash Flow/Total Sales                  0.39055         0.35407
# Operating Cash Flow/Total Debt                  28.85392        25.61557
# Operating Cash Flow/Shareholder"s Equity         0.55875         0.53394
# Fixed Asset Turnover Ratio                       2.90813         3.13408
# YOY Sales Growth Rate                            0.07572         0.24371
# YOY EBIT Growth Rate                            -0.02974         0.14724
# Total shareholders" funds                754886314.00000 770367465.00000
# Company_name                                    -6.00000        -5.00000
#
#                                                        4
# Row                                              1.00000
# Year                                          2014.00000
# Year Encoded                                    -4.00000
# Dummy Coded :Healthy=1; NPA= 0                   1.00000
# Asset_turnover                                   1.42893
# Receivable_turnover(new)                         6.10799
# Inventory_turnover                               0.00000
# Cash_ratio                                       1.21196
# Quick_ratio                                      0.61504
# Current_ratio                                    3.18905
# ROA(new)                                         0.43305
# ROE(new)                                         0.55367
# ROS(new)                                         0.30306
# debt_asset                                       0.02708
# debt_equity                                      0.03462
# debt_income                                      0.06253
# Interest_coverage                            20313.06221
# Asset_coverage                                  21.50976
# EBIT_Sales                                       0.30306
# Sales_CE                                         1.82694
# ROCE_CE                                          0.55367
# Changeinsales_Industry                           0.11152
# Grossvaluedadded                           1683937.55430
# Ln_GVA                                          14.33665
# Operating Cash Flow/Total Sales                  0.32075
# Operating Cash Flow/Total Debt                  16.92720
# Operating Cash Flow/Shareholder"s Equity         0.58600
# Fixed Asset Turnover Ratio                       3.99127
# YOY Sales Growth Rate                           -0.08577
# YOY EBIT Growth Rate                            -0.22265
# Total shareholders" funds                790918031.00000
# Company_name                                    -4.00000

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Row                                       9000 non-null   int32
#  1   Year                                      9000 non-null   int32
#  2   Year Encoded                              9000 non-null   int32
#  3   Dummy Coded :Healthy=1; NPA= 0            9000 non-null   int32
#  4   Asset_turnover                            9000 non-null   float64
#  5   Receivable_turnover(new)                  9000 non-null   float64
#  6   Inventory_turnover                        9000 non-null   float64
#  7   Cash_ratio                                9000 non-null   float64
#  8   Quick_ratio                               9000 non-null   float64
#  9   Current_ratio                             9000 non-null   float64
#  10  ROA(new)                                  9000 non-null   float64
#  11  ROE(new)                                  9000 non-null   float64
#  12  ROS(new)                                  9000 non-null   float64
#  13  debt_asset                                9000 non-null   float64
#  14  debt_equity                               9000 non-null   float64
#  15  debt_income                               9000 non-null   float64
#  16  Interest_coverage                         9000 non-null   float64
#  17  Asset_coverage                            9000 non-null   float64
#  18  EBIT_Sales                                9000 non-null   float64
#  19  Sales_CE                                  9000 non-null   float64
#  20  ROCE_CE                                   9000 non-null   float64
#  21  Changeinsales_Industry                    9000 non-null   float64
#  22  Grossvaluedadded                          9000 non-null   float64
#  23  Ln_GVA                                    9000 non-null   float64
#  24  Operating Cash Flow/Total Sales           9000 non-null   float64
#  25  Operating Cash Flow/Total Debt            9000 non-null   float64
#  26  Operating Cash Flow/Shareholder"s Equity  9000 non-null   float64
#  27  Fixed Asset Turnover Ratio                9000 non-null   float64
#  28  YOY Sales Growth Rate                     9000 non-null   float64
#  29  YOY EBIT Growth Rate                      9000 non-null   float64
#  30  Total shareholders" funds                 9000 non-null   float64
#  31  Company_name                              9000 non-null   int64
# dtypes: float64(27), int32(4), int64(1)
# memory usage: 2.1 MB

# %%
output_file_name =  './Output/Bankruptcy-data-' + str(datetime.now().strftime('%Y_%m_%d_%H_%M_%S')) + '.csv'
new_df.to_csv(output_file_name, index = False)

# %% [markdown]
# ### END
